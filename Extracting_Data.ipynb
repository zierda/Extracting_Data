# %%
import yfinance as yf

# Extract stock data for Tesla for the past year
tesla_revenue = yf.download('TSLA', start='2023-01-01', end='2024-01-01')

# Reset index
tesla_revenue.reset_index(inplace=True)

# Display the first five rows
tesla_revenue.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2023-01-03  118.470001  118.800003  104.639999  108.099998  108.099998
# 1 2023-01-04  109.110001  114.589996  107.519997  113.639999  113.639999
# 2 2023-01-05  110.510002  111.750000  107.160004  110.339996  110.339996
# 3 2023-01-06  103.000000  114.389999  101.809998  113.059998  113.059998
# 4 2023-01-09  118.959999  123.519997  117.110001  119.769997  119.769997
#
#       Volume
# 0  231402800
# 1  180389000
# 2  157986300
# 3  220911100
# 4  190284000

# %%
# Display the last five rows
print(tesla_revenue.tail())
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 245 2023-12-22  256.760010  258.220001  251.369995  252.539993  252.539993
# 246 2023-12-26  254.490005  257.970001  252.910004  256.609985  256.609985
# 247 2023-12-27  258.350006  263.339996  257.519989  261.440002  261.440002
# 248 2023-12-28  263.660004  265.130005  252.710007  253.179993  253.179993
# 249 2023-12-29  255.100006  255.190002  247.429993  248.479996  248.479996
#
#         Volume
# 245   93249800
# 246   86892400
# 247  106494400
# 248  113619900
# 249  100615300

# %%
import yfinance as yf

# Extract stock data for GameStop (GME)
gme_revenue = yf.download('GME')

# Reset the index of the dataframe
gme_revenue.reset_index(inplace=True)

# Save the dataframe to a CSV file if needed
# gme_data.to_csv('gme_data.csv', index=False)  # Uncomment this line if you want to save to a file

# Display the first five rows of the dataframe
print(gme_revenue.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date     Open     High      Low    Close  Adj Close    Volume
# 0 2002-02-13  2.40625  2.51500  2.38125  2.51250   1.691666  76216000
# 1 2002-02-14  2.54375  2.54875  2.48125  2.50000   1.683250  11021600
# 2 2002-02-15  2.50000  2.50625  2.46250  2.48750   1.674834   8389600
# 3 2002-02-19  2.47500  2.47500  2.34375  2.38750   1.607504   7410400
# 4 2002-02-20  2.40000  2.46875  2.38125  2.46875   1.662210   6892800

# %%
print(gme_revenue.tail())
# Out:
#            Date   Open       High        Low      Close  Adj Close     Volume
# 5608 2024-05-24  18.42  19.680000  17.700001  19.000000  19.000000   41886700
# 5609 2024-05-28  23.10  26.660000  21.150000  23.780001  23.780001  105077600
# 5610 2024-05-29  22.00  22.980000  21.049999  21.240000  21.240000   26921200
# 5611 2024-05-30  21.02  22.700001  20.100000  22.610001  22.610001   24508800
# 5612 2024-05-31  22.58  23.719999  21.680000  23.139999  23.139999   22084500

# %%
pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.2/162.2 kB 1.3 MB/s eta 0:00:00a 0:00:01
# ...
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 2.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 2.8 MB/s eta 0:00:00a 0:00:01
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 2.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 2.9 MB/s eta 0:00:0000:0100:01
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Define the make_graph function
def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data.index, data['Close'], label='Close Price', color='blue')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Close Price')
    plt.legend()
    plt.grid(True)
    plt.show()

# Fetch Tesla stock data
tesla_data = yf.download('TSLA')

# Plot the graph with a title
make_graph(tesla_data, title='Tesla Stock Price')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Define the make_graph function
def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data.index, data['Close'], label='Close Price', color='blue')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Close Price')
    plt.legend()
    plt.grid(True)
    plt.show()

# Fetch GameStop stock data
gme_data = yf.download('GME')

# Plot the graph with a title
make_graph(gme_data, title='GameStop Stock Price')
# Out:
# [*********************100%%**********************]  1 of 1 completed
